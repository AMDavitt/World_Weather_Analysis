# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 753

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | muyezerskiy
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | stip
# City not found. Skipping...
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | sarangani
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 1 | srednekolymsk
# Processing Record 15 of Set 1 | saldanha
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | oriximina
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | kendari
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | giulesti
# Processing Record 22 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | solok
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | ossora
# Processing Record 28 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | saint-georges
# Processing Record 34 of Set 1 | alta floresta
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | beringovskiy
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | sorland
# Processing Record 44 of Set 1 | longhua
# Processing Record 45 of Set 1 | ahipara
# Processing Record 46 of Set 1 | acajutla
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | ouadda
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | opuwo
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | marzuq
# Processing Record 11 of Set 2 | nelson bay
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | pingliang
# Processing Record 14 of Set 2 | gizo
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | necochea
# Processing Record 19 of Set 2 | coahuayana
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | mbengwi
# Processing Record 25 of Set 2 | pochutla
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | northam
# Processing Record 31 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 2 | acari
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | vostok
# Processing Record 35 of Set 2 | alto parana
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | hede
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | havre-saint-pierre
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | qibili
# City not found. Skipping...
# Processing Record 44 of Set 2 | mangai
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | gravelbourg
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | arlit
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | tessalit
# Processing Record 1 of Set 3 | santa lucia
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | ashqelon
# Processing Record 5 of Set 3 | veydelevka
# Processing Record 6 of Set 3 | shcholkine
# City not found. Skipping...
# Processing Record 7 of Set 3 | assens
# Processing Record 8 of Set 3 | zhigansk
# Processing Record 9 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | farafangana
# Processing Record 13 of Set 3 | alugan
# Processing Record 14 of Set 3 | brigantine
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | floro
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | dargaville
# Processing Record 19 of Set 3 | enshi
# Processing Record 20 of Set 3 | bonavista
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | sharan
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | sept-iles
# Processing Record 25 of Set 3 | manakara
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | hervey bay
# Processing Record 29 of Set 3 | qui nhon
# Processing Record 30 of Set 3 | cayenne
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | bethanien
# Processing Record 33 of Set 3 | vierzon
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | copiapo
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | busselton
# Processing Record 43 of Set 3 | kupang
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | sovetskaya
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | kedougou
# Processing Record 50 of Set 3 | camapua
# Processing Record 1 of Set 4 | bom despacho
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 4 | lompoc
# Processing Record 5 of Set 4 | severskaya
# Processing Record 6 of Set 4 | hovd
# Processing Record 7 of Set 4 | butaritari
# Processing Record 8 of Set 4 | inta
# Processing Record 9 of Set 4 | macau
# Processing Record 10 of Set 4 | dong hoi
# Processing Record 11 of Set 4 | marsa matruh
# Processing Record 12 of Set 4 | korla
# Processing Record 13 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 14 of Set 4 | roald
# Processing Record 15 of Set 4 | lata
# Processing Record 16 of Set 4 | ponca city
# Processing Record 17 of Set 4 | muisne
# Processing Record 18 of Set 4 | swan hill
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 21 of Set 4 | lufilufi
# Processing Record 22 of Set 4 | harper
# Processing Record 23 of Set 4 | baculin
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | chabahar
# Processing Record 26 of Set 4 | san vicente
# Processing Record 27 of Set 4 | flin flon
# Processing Record 28 of Set 4 | esmeralda
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | mantua
# Processing Record 31 of Set 4 | huixquilucan
# Processing Record 32 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 4 | mehamn
# Processing Record 35 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 4 | naze
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | tabuk
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | ambilobe
# Processing Record 43 of Set 4 | valparaiso
# Processing Record 44 of Set 4 | krasnoselkup
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | bilibino
# Processing Record 48 of Set 4 | wiarton
# Processing Record 49 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 4 | berlevag
# Processing Record 1 of Set 5 | codrington
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | gobabis
# Processing Record 4 of Set 5 | hasaki
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 5 | kerema
# Processing Record 8 of Set 5 | saint-augustin
# Processing Record 9 of Set 5 | north vernon
# Processing Record 10 of Set 5 | kirkwood
# Processing Record 11 of Set 5 | sosnovskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | sabha
# Processing Record 14 of Set 5 | san quintin
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | umm kaddadah
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 5 | tsaratanana
# Processing Record 21 of Set 5 | kununurra
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | traipu
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | coari
# Processing Record 28 of Set 5 | booue
# Processing Record 29 of Set 5 | warragul
# Processing Record 30 of Set 5 | sarauli
# Processing Record 31 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 5 | bratsk
# Processing Record 33 of Set 5 | atalanti
# Processing Record 34 of Set 5 | sabang
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | alvorada
# Processing Record 37 of Set 5 | aksarka
# Processing Record 38 of Set 5 | holme
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | riyadh
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | inhambane
# Processing Record 43 of Set 5 | chicama
# Processing Record 44 of Set 5 | tuatapere
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | sambava
# Processing Record 47 of Set 5 | trujillo
# Processing Record 48 of Set 5 | sechura
# Processing Record 49 of Set 5 | iisalmi
# Processing Record 50 of Set 5 | santa maria
# Processing Record 1 of Set 6 | vaitape
# Processing Record 2 of Set 6 | sarab
# Processing Record 3 of Set 6 | qiongshan
# Processing Record 4 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | umm lajj
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | sinop
# Processing Record 9 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 6 | tabou
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | lashio
# Processing Record 13 of Set 6 | anloga
# Processing Record 14 of Set 6 | meadow lake
# Processing Record 15 of Set 6 | afgoye
# City not found. Skipping...
# Processing Record 16 of Set 6 | dauriya
# Processing Record 17 of Set 6 | mattru
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | brahmapuri
# City not found. Skipping...
# Processing Record 20 of Set 6 | sorokino
# Processing Record 21 of Set 6 | gwadar
# Processing Record 22 of Set 6 | okahandja
# Processing Record 23 of Set 6 | liverpool
# Processing Record 24 of Set 6 | bago
# Processing Record 25 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 6 | ponta delgada
# Processing Record 27 of Set 6 | clarksdale
# Processing Record 28 of Set 6 | sobolevo
# Processing Record 29 of Set 6 | hambantota
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | catuday
# Processing Record 32 of Set 6 | edgewater
# Processing Record 33 of Set 6 | les cayes
# Processing Record 34 of Set 6 | san nicolas
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | lerwick
# Processing Record 38 of Set 6 | palafrugell
# Processing Record 39 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 6 | namtsy
# Processing Record 41 of Set 6 | quelimane
# Processing Record 42 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of Set 6 | terrak
# Processing Record 44 of Set 6 | roscrea
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | labuhan
# Processing Record 47 of Set 6 | ayagoz
# Processing Record 48 of Set 6 | cockburn town
# Processing Record 49 of Set 6 | zhanaozen
# Processing Record 50 of Set 6 | benemerito de las americas
# Processing Record 1 of Set 7 | buraydah
# Processing Record 2 of Set 7 | lianzhou
# Processing Record 3 of Set 7 | ovalle
# Processing Record 4 of Set 7 | nuuk
# Processing Record 5 of Set 7 | kande
# Processing Record 6 of Set 7 | garzon
# Processing Record 7 of Set 7 | three hills
# Processing Record 8 of Set 7 | crieff
# Processing Record 9 of Set 7 | inyonga
# Processing Record 10 of Set 7 | morant bay
# Processing Record 11 of Set 7 | stonewall
# Processing Record 12 of Set 7 | maceio
# Processing Record 13 of Set 7 | harlingen
# Processing Record 14 of Set 7 | antoniny
# Processing Record 15 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 7 | soyo
# Processing Record 17 of Set 7 | faya
# Processing Record 18 of Set 7 | harnai
# Processing Record 19 of Set 7 | lazarev
# Processing Record 20 of Set 7 | fort nelson
# Processing Record 21 of Set 7 | tanabe
# Processing Record 22 of Set 7 | ewa beach
# Processing Record 23 of Set 7 | elat
# Processing Record 24 of Set 7 | orocue
# Processing Record 25 of Set 7 | mayo
# Processing Record 26 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 27 of Set 7 | gamba
# Processing Record 28 of Set 7 | port-gentil
# Processing Record 29 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 7 | ureki
# Processing Record 31 of Set 7 | tancheng
# Processing Record 32 of Set 7 | urumqi
# Processing Record 33 of Set 7 | antalaha
# Processing Record 34 of Set 7 | quatre cocos
# Processing Record 35 of Set 7 | santa isabel do rio negro
# Processing Record 36 of Set 7 | marsabit
# Processing Record 37 of Set 7 | alofi
# Processing Record 38 of Set 7 | ouesso
# Processing Record 39 of Set 7 | siolim
# City not found. Skipping...
# Processing Record 40 of Set 7 | ambunti
# Processing Record 41 of Set 7 | mount isa
# Processing Record 42 of Set 7 | salinopolis
# Processing Record 43 of Set 7 | constantine
# Processing Record 44 of Set 7 | sao jose da coroa grande
# Processing Record 45 of Set 7 | aquidauana
# Processing Record 46 of Set 7 | touros
# Processing Record 47 of Set 7 | shenjiamen
# Processing Record 48 of Set 7 | pandan
# Processing Record 49 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 7 | donskoye
# Processing Record 1 of Set 8 | padang
# Processing Record 2 of Set 8 | klyuchevskiy
# Processing Record 3 of Set 8 | muli
# Processing Record 4 of Set 8 | stege
# Processing Record 5 of Set 8 | prieska
# Processing Record 6 of Set 8 | dakar
# Processing Record 7 of Set 8 | north platte
# Processing Record 8 of Set 8 | walvis bay
# Processing Record 9 of Set 8 | manturovo
# Processing Record 10 of Set 8 | livanatai
# Processing Record 11 of Set 8 | bogovarovo
# Processing Record 12 of Set 8 | olean
# Processing Record 13 of Set 8 | havoysund
# Processing Record 14 of Set 8 | martapura
# Processing Record 15 of Set 8 | kahului
# Processing Record 16 of Set 8 | maiduguri
# Processing Record 17 of Set 8 | choma
# Processing Record 18 of Set 8 | makakilo city
# Processing Record 19 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | kigonsera
# Processing Record 21 of Set 8 | bundaberg
# Processing Record 22 of Set 8 | bandundu
# Processing Record 23 of Set 8 | dunedin
# Processing Record 24 of Set 8 | taksimo
# Processing Record 25 of Set 8 | okhotsk
# Processing Record 26 of Set 8 | mogadishu
# Processing Record 27 of Set 8 | hammonton
# Processing Record 28 of Set 8 | nanchong
# Processing Record 29 of Set 8 | bida
# Processing Record 30 of Set 8 | fare
# Processing Record 31 of Set 8 | chokurdakh
# Processing Record 32 of Set 8 | san carlos de bariloche
# Processing Record 33 of Set 8 | colleferro
# Processing Record 34 of Set 8 | nesna
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | itarema
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | grajau
# Processing Record 39 of Set 8 | jaque
# Processing Record 40 of Set 8 | hastings
# Processing Record 41 of Set 8 | souillac
# Processing Record 42 of Set 8 | rudnichnyy
# Processing Record 43 of Set 8 | the valley
# Processing Record 44 of Set 8 | ardesen
# Processing Record 45 of Set 8 | izazi
# Processing Record 46 of Set 8 | portel
# Processing Record 47 of Set 8 | washington
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | dingle
# Processing Record 50 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 9 | stiubieni
# Processing Record 2 of Set 9 | warrnambool
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | karatau
# Processing Record 5 of Set 9 | jarvakandi
# Processing Record 6 of Set 9 | shumskiy
# Processing Record 7 of Set 9 | mlowo
# Processing Record 8 of Set 9 | port hedland
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | smithers
# Processing Record 11 of Set 9 | jieshi
# Processing Record 12 of Set 9 | verkhoturye
# Processing Record 13 of Set 9 | buala
# Processing Record 14 of Set 9 | ranghulu
# Processing Record 15 of Set 9 | tefe
# Processing Record 16 of Set 9 | jawhar
# Processing Record 17 of Set 9 | nikolsk
# Processing Record 18 of Set 9 | hutchinson
# Processing Record 19 of Set 9 | derzhavinsk
# Processing Record 20 of Set 9 | vila velha
# Processing Record 21 of Set 9 | te anau
# Processing Record 22 of Set 9 | zunyi
# Processing Record 23 of Set 9 | yumen
# Processing Record 24 of Set 9 | shitanjing
# Processing Record 25 of Set 9 | aller
# Processing Record 26 of Set 9 | boa vista
# Processing Record 27 of Set 9 | marathon
# Processing Record 28 of Set 9 | vardo
# Processing Record 29 of Set 9 | hualmay
# Processing Record 30 of Set 9 | poum
# Processing Record 31 of Set 9 | kiama
# Processing Record 32 of Set 9 | changji
# Processing Record 33 of Set 9 | huarmey
# Processing Record 34 of Set 9 | daulatpur
# Processing Record 35 of Set 9 | talcahuano
# Processing Record 36 of Set 9 | ferkessedougou
# Processing Record 37 of Set 9 | miri
# Processing Record 38 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 9 | bergerac
# Processing Record 40 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | shibetsu
# Processing Record 42 of Set 9 | cabinda
# Processing Record 43 of Set 9 | tolentino
# Processing Record 44 of Set 9 | saquena
# Processing Record 45 of Set 9 | fengrun
# Processing Record 46 of Set 9 | chegem
# Processing Record 47 of Set 9 | portland
# Processing Record 48 of Set 9 | lodja
# Processing Record 49 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 10 | torbat-e jam
# Processing Record 2 of Set 10 | chiang khong
# Processing Record 3 of Set 10 | almetyevsk
# Processing Record 4 of Set 10 | avera
# Processing Record 5 of Set 10 | fairbanks
# Processing Record 6 of Set 10 | cherskiy
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | sayyan
# Processing Record 9 of Set 10 | klaksvik
# Processing Record 10 of Set 10 | sestri levante
# Processing Record 11 of Set 10 | great bend
# Processing Record 12 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 10 | yerbogachen
# Processing Record 14 of Set 10 | kavieng
# Processing Record 15 of Set 10 | port macquarie
# Processing Record 16 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 10 | taoudenni
# Processing Record 18 of Set 10 | asau
# Processing Record 19 of Set 10 | kamaishi
# Processing Record 20 of Set 10 | kidal
# Processing Record 21 of Set 10 | semporna
# Processing Record 22 of Set 10 | xining
# Processing Record 23 of Set 10 | chemal
# Processing Record 24 of Set 10 | paragominas
# Processing Record 25 of Set 10 | bazarnyy karabulak
# Processing Record 26 of Set 10 | methoni
# Processing Record 27 of Set 10 | ville-marie
# Processing Record 28 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 10 | elliot lake
# Processing Record 30 of Set 10 | pangnirtung
# Processing Record 31 of Set 10 | campos novos
# Processing Record 32 of Set 10 | honiara
# Processing Record 33 of Set 10 | palestine
# Processing Record 34 of Set 10 | lastoursville
# Processing Record 35 of Set 10 | lang son
# Processing Record 36 of Set 10 | college
# Processing Record 37 of Set 10 | male
# Processing Record 38 of Set 10 | salinas
# Processing Record 39 of Set 10 | yeniseysk
# Processing Record 40 of Set 10 | thinadhoo
# Processing Record 41 of Set 10 | mazara del vallo
# Processing Record 42 of Set 10 | cabra
# Processing Record 43 of Set 10 | rassvet
# Processing Record 44 of Set 10 | jiwani
# Processing Record 45 of Set 10 | chiang klang
# Processing Record 46 of Set 10 | esperance
# Processing Record 47 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 10 | akyab
# Processing Record 49 of Set 10 | manaure
# Processing Record 50 of Set 10 | sandane
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | sallanches
# Processing Record 3 of Set 11 | melfort
# Processing Record 4 of Set 11 | batagay
# Processing Record 5 of Set 11 | puerto escondido
# Processing Record 6 of Set 11 | chapais
# Processing Record 7 of Set 11 | leshukonskoye
# Processing Record 8 of Set 11 | bogalusa
# Processing Record 9 of Set 11 | jishou
# Processing Record 10 of Set 11 | ugoofaaru
# Processing Record 11 of Set 11 | san pedro
# Processing Record 12 of Set 11 | evanston
# Processing Record 13 of Set 11 | san cosme y damian
# Processing Record 14 of Set 11 | merauke
# Processing Record 15 of Set 11 | suileng
# Processing Record 16 of Set 11 | saint-francois
# Processing Record 17 of Set 11 | lakota
# Processing Record 18 of Set 11 | domoni
# Processing Record 19 of Set 11 | mareeba
# Processing Record 20 of Set 11 | maun
# Processing Record 21 of Set 11 | brekstad
# Processing Record 22 of Set 11 | cedar city
# Processing Record 23 of Set 11 | port lincoln
# Processing Record 24 of Set 11 | kuytun
# Processing Record 25 of Set 11 | tual
# Processing Record 26 of Set 11 | ciudad bolivar
# Processing Record 27 of Set 11 | imeni poliny osipenko
# Processing Record 28 of Set 11 | alakurtti
# Processing Record 29 of Set 11 | yar-sale
# Processing Record 30 of Set 11 | paamiut
# Processing Record 31 of Set 11 | lima
# Processing Record 32 of Set 11 | guerrero negro
# Processing Record 33 of Set 11 | shebalino
# Processing Record 34 of Set 11 | pionerskiy
# Processing Record 35 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 11 | biak
# Processing Record 37 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 11 | pouebo
# Processing Record 39 of Set 11 | ericeira
# Processing Record 40 of Set 11 | ouallam
# Processing Record 41 of Set 11 | bayangol
# Processing Record 42 of Set 11 | bermeo
# Processing Record 43 of Set 11 | hofn
# Processing Record 44 of Set 11 | grand island
# Processing Record 45 of Set 11 | novyy urengoy
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | ola
# Processing Record 48 of Set 11 | saint-joseph
# Processing Record 49 of Set 11 | shamkhal
# Processing Record 50 of Set 11 | brandon
# Processing Record 1 of Set 12 | mahajanga
# Processing Record 2 of Set 12 | sampit
# Processing Record 3 of Set 12 | akdagmadeni
# Processing Record 4 of Set 12 | dawei
# Processing Record 5 of Set 12 | vrangel
# Processing Record 6 of Set 12 | matara
# Processing Record 7 of Set 12 | nova olimpia
# Processing Record 8 of Set 12 | mbaiki
# Processing Record 9 of Set 12 | bowmore
# Processing Record 10 of Set 12 | mut
# Processing Record 11 of Set 12 | luganville
# Processing Record 12 of Set 12 | ahuimanu
# Processing Record 13 of Set 12 | corinth
# Processing Record 14 of Set 12 | havre
# Processing Record 15 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 16 of Set 12 | emerald
# Processing Record 17 of Set 12 | chingirlau
# Processing Record 18 of Set 12 | kutum
# Processing Record 19 of Set 12 | oxbow
# Processing Record 20 of Set 12 | snezhnogorsk
# Processing Record 21 of Set 12 | varzea da palma
# Processing Record 22 of Set 12 | yulara
# Processing Record 23 of Set 12 | silver city
# Processing Record 24 of Set 12 | kuito
# Processing Record 25 of Set 12 | boguchany
# Processing Record 26 of Set 12 | santa teresa
# Processing Record 27 of Set 12 | birao
# Processing Record 28 of Set 12 | teeli
# Processing Record 29 of Set 12 | loubomo
# Processing Record 30 of Set 12 | koumac
# Processing Record 31 of Set 12 | sterlibashevo
# Processing Record 32 of Set 12 | lac du bonnet
# Processing Record 33 of Set 12 | tongzi
# Processing Record 34 of Set 12 | troitskoye
# Processing Record 35 of Set 12 | san francisco
# Processing Record 36 of Set 12 | lodeynoye pole
# Processing Record 37 of Set 12 | mahon
# Processing Record 38 of Set 12 | colotlan
# Processing Record 39 of Set 12 | qaqortoq
# Processing Record 40 of Set 12 | grafton
# Processing Record 41 of Set 12 | kasama
# Processing Record 42 of Set 12 | qostanay
# Processing Record 43 of Set 12 | kungurtug
# Processing Record 44 of Set 12 | genhe
# Processing Record 45 of Set 12 | sebeta
# Processing Record 46 of Set 12 | chumikan
# Processing Record 47 of Set 12 | wamba
# Processing Record 48 of Set 12 | alpatovo
# Processing Record 49 of Set 12 | charters towers
# Processing Record 50 of Set 12 | durban
# Processing Record 1 of Set 13 | heihe
# Processing Record 2 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 13 | sohag
# Processing Record 4 of Set 13 | coquimbo
# Processing Record 5 of Set 13 | den helder
# Processing Record 6 of Set 13 | egvekinot
# Processing Record 7 of Set 13 | pekin
# Processing Record 8 of Set 13 | leh
# Processing Record 9 of Set 13 | kayes
# Processing Record 10 of Set 13 | namatanai
# Processing Record 11 of Set 13 | sugar hill
# Processing Record 12 of Set 13 | zalantun
# Processing Record 13 of Set 13 | abha
# Processing Record 14 of Set 13 | shenzhen
# Processing Record 15 of Set 13 | kimbe
# Processing Record 16 of Set 13 | svetlogorsk
# Processing Record 17 of Set 13 | kushikino
# Processing Record 18 of Set 13 | keffi
# Processing Record 19 of Set 13 | pitkyaranta
# Processing Record 20 of Set 13 | tharrawaddy
# City not found. Skipping...
# Processing Record 21 of Set 13 | camacha
# Processing Record 22 of Set 13 | sisimiut
# Processing Record 23 of Set 13 | atambua
# Processing Record 24 of Set 13 | touba
# Processing Record 25 of Set 13 | cheyenne
# Processing Record 26 of Set 13 | kayankulam
# Processing Record 27 of Set 13 | saint anthony
# Processing Record 28 of Set 13 | halifax
# Processing Record 29 of Set 13 | nouakchott
# Processing Record 30 of Set 13 | jumla
# Processing Record 31 of Set 13 | narsaq
# Processing Record 32 of Set 13 | sao paulo do potengi
# Processing Record 33 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 13 | litovko
# Processing Record 35 of Set 13 | beipiao
# Processing Record 36 of Set 13 | golden
# Processing Record 37 of Set 13 | youghal
# Processing Record 38 of Set 13 | dan khun thot
# Processing Record 39 of Set 13 | komsomolskiy
# Processing Record 40 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 41 of Set 13 | palu
# Processing Record 42 of Set 13 | arona
# Processing Record 43 of Set 13 | mayumba
# Processing Record 44 of Set 13 | tutoia
# Processing Record 45 of Set 13 | loiza
# Processing Record 46 of Set 13 | arman
# Processing Record 47 of Set 13 | kinango
# Processing Record 48 of Set 13 | baherden
# Processing Record 49 of Set 13 | banos
# Processing Record 50 of Set 13 | sur
# Processing Record 1 of Set 14 | rochester
# Processing Record 2 of Set 14 | tiarei
# Processing Record 3 of Set 14 | ostersund
# Processing Record 4 of Set 14 | koslan
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | porto walter
# Processing Record 7 of Set 14 | miyazu
# Processing Record 8 of Set 14 | marawi
# Processing Record 9 of Set 14 | andenes
# Processing Record 10 of Set 14 | tsiroanomandidy
# Processing Record 11 of Set 14 | pangai
# Processing Record 12 of Set 14 | havelock
# Processing Record 13 of Set 14 | antibes
# Processing Record 14 of Set 14 | talas
# Processing Record 15 of Set 14 | pangody
# Processing Record 16 of Set 14 | flinders
# Processing Record 17 of Set 14 | celestun
# Processing Record 18 of Set 14 | bow island
# Processing Record 19 of Set 14 | amahai
# Processing Record 20 of Set 14 | kitob
# Processing Record 21 of Set 14 | pathein
# Processing Record 22 of Set 14 | zhigalovo
# Processing Record 23 of Set 14 | adrar
# Processing Record 24 of Set 14 | grindavik
# Processing Record 25 of Set 14 | progreso
# Processing Record 26 of Set 14 | deputatskiy
# Processing Record 27 of Set 14 | sibolga
# Processing Record 28 of Set 14 | virginia beach
# Processing Record 29 of Set 14 | irbeyskoye
# Processing Record 30 of Set 14 | bohemia
# Processing Record 31 of Set 14 | rawson
# Processing Record 32 of Set 14 | raymond
# Processing Record 33 of Set 14 | voyvozh
# Processing Record 34 of Set 14 | tahta
# Processing Record 35 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 36 of Set 14 | alghero
# Processing Record 37 of Set 14 | tokonou
# Processing Record 38 of Set 14 | kushima
# Processing Record 39 of Set 14 | hobyo
# Processing Record 40 of Set 14 | kelvington
# Processing Record 41 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 14 | misratah
# Processing Record 43 of Set 14 | uray
# Processing Record 44 of Set 14 | englewood
# Processing Record 45 of Set 14 | santa cruz de tenerife
# Processing Record 46 of Set 14 | obigarm
# Processing Record 47 of Set 14 | pyapon
# Processing Record 48 of Set 14 | kostomuksha
# Processing Record 49 of Set 14 | kizukuri
# Processing Record 50 of Set 14 | cangucu
# Processing Record 1 of Set 15 | raudeberg
# Processing Record 2 of Set 15 | eyemouth
# Processing Record 3 of Set 15 | yavaros
# Processing Record 4 of Set 15 | les herbiers
# Processing Record 5 of Set 15 | port hawkesbury
# Processing Record 6 of Set 15 | sainte-rose
# Processing Record 7 of Set 15 | nabire
# Processing Record 8 of Set 15 | bequimao
# Processing Record 9 of Set 15 | mizdah
# Processing Record 10 of Set 15 | poya
# Processing Record 11 of Set 15 | pomabamba
# Processing Record 12 of Set 15 | mukhen
# Processing Record 13 of Set 15 | panuco
# Processing Record 14 of Set 15 | tyukhtet
# Processing Record 15 of Set 15 | chirongui
# Processing Record 16 of Set 15 | shalya
# Processing Record 17 of Set 15 | aripuana
# Processing Record 18 of Set 15 | cabedelo
# Processing Record 19 of Set 15 | san luis rio colorado
# Processing Record 20 of Set 15 | chernyshevskiy
# Processing Record 21 of Set 15 | seoul
# Processing Record 22 of Set 15 | hamilton
# Processing Record 23 of Set 15 | mvangue
# Processing Record 24 of Set 15 | palasa
# Processing Record 25 of Set 15 | saint-pierre
# Processing Record 26 of Set 15 | karratha
# Processing Record 27 of Set 15 | sulina
# Processing Record 28 of Set 15 | vikulovo
# Processing Record 29 of Set 15 | chirilagua
# Processing Record 30 of Set 15 | terme
# Processing Record 31 of Set 15 | skiathos
# Processing Record 32 of Set 15 | puerto del rosario
# Processing Record 33 of Set 15 | san jeronimo
# Processing Record 34 of Set 15 | tambovka
# Processing Record 35 of Set 15 | marand
# Processing Record 36 of Set 15 | salamiyah
# Processing Record 37 of Set 15 | sao joao del rei
# Processing Record 38 of Set 15 | plettenberg bay
# Processing Record 39 of Set 15 | acapulco
# Processing Record 40 of Set 15 | aykino
# Processing Record 41 of Set 15 | sibiti
# Processing Record 42 of Set 15 | shush
# Processing Record 43 of Set 15 | khasan
# Processing Record 44 of Set 15 | tubuala
# Processing Record 45 of Set 15 | san joaquin
# Processing Record 46 of Set 15 | hnaberd
# Processing Record 47 of Set 15 | saint-louis
# Processing Record 48 of Set 15 | kamenka
# Processing Record 49 of Set 15 | coracao de maria
# Processing Record 50 of Set 15 | oktyabrskiy
# Processing Record 1 of Set 16 | nizhniy tsasuchey
# Processing Record 2 of Set 16 | luau
# Processing Record 3 of Set 16 | gariaband
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq      GL  77.4840  -69.3632     17.74        91         100
# 1   Muyezerskiy      RU  63.9333   31.6500     23.77        89          11
# 2  Longyearbyen      SJ  78.2186   15.6401     19.24        68          40
# 3     Jamestown      US  42.0970  -79.2353     52.02        93          98
# 4     Carnarvon      AU -24.8667  113.6333     79.79        37           0
# 5       Rikitea      PF -23.1203 -134.9692     77.63        84          71
# 6        Atuona      PF  -9.8000 -139.0333     79.18        74          10
# 7     Sarangani      PH   5.4033  125.4636     83.17        77          83
# 8   East London      ZA -33.0153   27.9116     64.11        80          17
# 9        Hobart      AU -42.8794  147.3294     57.25        74          20
#
#    Wind Speed Current Description
# 0        3.53     overcast clouds
# 1        4.43          few clouds
# 2        2.30    scattered clouds
# 3        1.99     overcast clouds
# 4       23.15           clear sky
# 5       19.95          light rain
# 6       15.59           clear sky
# 7       17.13       broken clouds
# 8        4.03          few clouds
# 9        5.75          few clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
